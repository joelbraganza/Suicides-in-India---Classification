# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r'D:\joel\UDEMY -\datasets and codes\Notebooks\.ipynb_checkpoints\Suicide dataset\Suicides_in_India.csv')
print (df.shape)
df.head() # 230k+ observations, 7 variables
# Out:
# (237519, 7)
#            State  Year Type_code                                 Type  Gender  \
# 0  A & N ISLANDS  2001    Causes                               Cancer    Male
# 1  A & N ISLANDS  2001    Causes                              Divorce    Male
# 2  A & N ISLANDS  2001    Causes                        Dowry Dispute  Female
# 3  A & N ISLANDS  2001    Causes  Ideological Causes/Hero Worshipping  Female
# 4  A & N ISLANDS  2001    Causes                   Illness (Aids/STD)  Female
#
#   Age_group  Total
# 0     15-29      0
# 1       60+      0
# 2       60+      0
# 3       60+      0
# 4      0-14      0

# %%
# Let's analyse every variable 
from matplotlib import pyplot as plt
df['State'].value_counts().plot(kind='bar')
plt.show()
print (len(df['State'].unique())) # 38 unique states/union territories
# every state/UT has pretty much the same no. of observations 6k+ (except TOTAL (STATES)        312
#                                                                         TOTAL (ALL INDIA)     312
#                                                                         TOTAL (UTs)           312)

df['Year'].value_counts().plot(kind='bar')
plt.show() # every year has pretty much the same no. of observations.
# Out:
# 38

# %%
print (df['Type_code'].unique())
df['Type_code'].value_counts().plot(kind='bar')
plt.show()
# the plot shows 'Causes' being the maximum category in 'Type' variable, followed by "means_adopted" & "Professional_Profile"
# "Education_Status" & "Social Status" being the minimum.

print (len(df['Type'].unique()))
df['Type'].value_counts().plot(kind='bar')
plt.show() # there are various reasons in the 'Type' variable with varying no. of observations for each class
# we can surely find its association with 'Type_code' variable by performing some relation tests.
# Out:
# ['Causes' 'Means_adopted' 'Professional_Profile' 'Education_Status'
#  'Social_Status']
# 69

# %%
print(df['Gender'].value_counts(),'\n')
print (df['Age_group'].value_counts(),'\n')
# the 'Gender' variable shows a very balanced np. of classes in both MAlE & FEMALE
# Age_group shows every group of 14 yrs showing the same(45k+) observations except 100+ ys old showing the least(11k+)

print (len(df['Total'].unique())) # there 2K+ unique values in 230k+ no. of observations
# can't make sense of this data, except maybe keep it as a categoric variable
# Out:
# Male      118879
# Female    118640
# Name: Gender, dtype: int64
#
# 15-29     45223
# 30-44     45193
# 45-59     45146
# 60+       45074
# 0-14      45027
# 0-100+    11856
# Name: Age_group, dtype: int64
#
# 2180
